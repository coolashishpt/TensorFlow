# %%
import tensorflow as tf
print("TensorFlow Running...")
# Out:
# TensorFlow Running...

# %%
# load and show an image with Pillow
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
# load the image
image = Image.open('Ashish.jpg')
arr = np.array(image)
# summarize some details about the image
print(image.format)
print(image.mode)
print(image.size)
# show the image
plt.imshow(arr)
plt.show()
# Out:
# JPEG
# RGB
# (1670, 2036)

# %%
from keras.datasets import mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
# x_train

# %%
# first_image = np.array(first_image)
first_image = x_train[5]
pixels = first_image.reshape((28, 28))
plt.imshow(pixels)
plt.show()

# %%
arr.shape
# Out:
# (2036, 1670, 3)

# %%
plt.imshow([(60,55,50)])
plt.show()

# %%
learning_rate = 0.01
training_epochs = 20
batch_size = 256
display_step = 1
examples_to_show = 10

# Network Parameters
n_hidden_1 = 256 # 1st layer num features
n_hidden_2 = 128 # 2nd layer num features
n_input = 10200360 # MNIST data input (img shape: 28*28)

# tf Graph input (only pictures)
X = tf.placeholder("float", (None, n_input))

weights = {
    'encoder_h1': tf.Variable(tf.random_normal([n_input, n_hidden_1])),
    'encoder_h2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2])),
    'decoder_h1': tf.Variable(tf.random_normal([n_hidden_2, n_hidden_1])),
    'decoder_h2': tf.Variable(tf.random_normal([n_hidden_1, n_input])),
}
biases = {
    'encoder_b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'encoder_b2': tf.Variable(tf.random_normal([n_hidden_2])),
    'decoder_b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'decoder_b2': tf.Variable(tf.random_normal([n_input])),
}

# %%
def encoder(x):
    # Encoder first layer with sigmoid activation #1
    layer_1 = tf.nn.sigmoid(tf.add(tf.matmul(x, weights['encoder_h1']), biases['encoder_b1']))
    # Encoder second layer with sigmoid activation #2
    layer_2 = tf.nn.sigmoid(tf.add(tf.matmul(layer_1, weights['encoder_h2']), biases['encoder_b2']))
    return layer_2

# %%
def decoder(x):
    # Decoder first layer with sigmoid activation #1
    layer_1 = tf.nn.sigmoid(tf.add(tf.matmul(x, weights['decoder_h1']),biases['decoder_b1']))
    # Decoder second layer with sigmoid activation #2
    layer_2 = tf.nn.sigmoid(tf.add(tf.matmul(layer_1, weights['decoder_h2']), biases['decoder_b2']))
    return layer_2

# %%
encoder_op = encoder(X)
decoder_op = decoder(encoder_op)

# Reconstructed Images
y_pred = decoder_op
# Targets (Labels) are the input data.
y_true = X
init = tf.global_variables_initializer()

# %%
sess = tf.Session()

# %%
sess.run(init)

# %%
_, c = sess.run([optimizer, cost], feed_dict={X: arr})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-618baae4adc5> in <module>()
# ----> 1 _, c = sess.run([optimizer, cost], feed_dict={X: arr})
#
# NameError: name 'sess' is not defined
